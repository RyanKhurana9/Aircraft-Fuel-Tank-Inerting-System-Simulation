# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install seaborn

# %%
df=pd.read_csv("/Users/ryankhurana/Desktop/Aircraft Fuel Tank & Inerting System Simulation/data/simulation_output.csv")

# %%
df.head()
# Out:
#    t_s     t_min  phase  altitude_m  fuel_mass_kg  ullage_volume_m3  \
# 0  0.0  0.000000  climb    0.000000       11998.9          3.001375
# 1  1.0  0.016667  climb    8.906667       11997.8          3.002750
# 2  2.0  0.033333  climb   17.813333       11996.7          3.004125
# 3  3.0  0.050000  climb   26.720000       11995.6          3.005500
# 4  4.0  0.066667  climb   35.626667       11994.5          3.006875
#
#    tank_pressure_Pa  tank_temperature_K  o2_fraction  inert_flow_mol_s  \
# 0     101325.000000          288.150000       0.2095               0.0
# 1     101218.044605          288.149936       0.2095               0.0
# 2     101111.180647          288.149807       0.2095               0.0
# 3     101004.408067          288.149614       0.2095               0.0
# 4     100897.726805          288.149357       0.2095               0.0
#
#    fuel_burn_kg_s
# 0             1.1
# 1             1.1
# 2             1.1
# 3             1.1
# 4             1.1

# %%
df.describe()
# Out:
#                 t_s         t_min    altitude_m  fuel_mass_kg  \
# count  10801.000000  10801.000000  10801.000000  10801.000000
# mean    5400.000000     90.000000   9499.564855   8212.272864
# std     3118.124463     51.968741   2657.028494   1896.193815
# min        0.000000      0.000000      0.000000   5279.200000
# 25%     2700.000000     45.000000  10688.000000   6538.900000
# 50%     5400.000000     90.000000  10688.000000   8158.900000
# 75%     8100.000000    135.000000  10688.000000   9778.900000
# max    10800.000000    180.000000  10688.000000  11998.900000
#
#        ullage_volume_m3  tank_pressure_Pa  tank_temperature_K   o2_fraction  \
# count      10801.000000      10801.000000        10801.000000  1.080100e+04
# mean           7.734659      30762.646875          229.593665  2.095000e-01
# std            2.370242      16778.945183           18.739459  5.073837e-16
# min            3.001375      23766.613346          218.681372  2.095000e-01
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10801 entries, 0 to 10800
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   t_s                 10801 non-null  float64
#  1   t_min               10801 non-null  float64
#  2   phase               10801 non-null  str
#  3   altitude_m          10801 non-null  float64
#  4   fuel_mass_kg        10801 non-null  float64
#  5   ullage_volume_m3    10801 non-null  float64
#  6   tank_pressure_Pa    10801 non-null  float64
#  7   tank_temperature_K  10801 non-null  float64
#  8   o2_fraction         10801 non-null  float64
#  9   inert_flow_mol_s    10801 non-null  float64
#  10  fuel_burn_kg_s      10801 non-null  float64
# dtypes: float64(10), str(1)
# memory usage: 928.3 KB

# %%
df_numerical = df.select_dtypes(include=['float64', 'int64'])

# %%
corr_matrix=df_numerical.corr()

# %%
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['t_s', 't_min', 'phase', 'altitude_m', 'fuel_mass_kg',
#        'ullage_volume_m3', 'tank_pressure_Pa', 'tank_temperature_K',
#        'o2_fraction', 'inert_flow_mol_s', 'fuel_burn_kg_s'],
#       dtype='str')

# %%
plt.figure(figsize=(10, 6))

plt.plot(df["fuel_mass_kg"], df["o2_fraction"])

plt.xlabel("Fuel Mass (kg)")
plt.ylabel("Oxygen Fraction")
plt.title("Fuel Mass vs Oxygen Concentration")

plt.show()

# %%
plt.plot(df['altitude_m'],df['tank_temperature_K'])

plt.xlabel('Altitude (m)')
plt.ylabel('Tank Temperature (K)')
plt.title('Tank Temperature vs Altitude')
plt.grid()

# %%
df.columns
# Out:
# Index(['t_s', 't_min', 'phase', 'altitude_m', 'fuel_mass_kg',
#        'ullage_volume_m3', 'tank_pressure_Pa', 'tank_temperature_K',
#        'o2_fraction', 'inert_flow_mol_s', 'fuel_burn_kg_s'],
#       dtype='str')

# %%
plt.plot(df['fuel_mass_kg'],df['ullage_volume_m3'])
plt.xlabel('Fuel Mass (kg)')
plt.ylabel('Ullage Volume (m^3)')
plt.title('Ullage Volume vs Fuel Mass')
plt.grid()

# %%
df.columns
# Out:
# Index(['t_s', 't_min', 'phase', 'altitude_m', 'fuel_mass_kg',
#        'ullage_volume_m3', 'tank_pressure_Pa', 'tank_temperature_K',
#        'o2_fraction', 'inert_flow_mol_s', 'fuel_burn_kg_s'],
#       dtype='str')

# %%
df["tank_temperature_C"]=df["tank_temperature_K"]-273.15

# %%
df[["tank_temperature_K","tank_temperature_C"]].head()
# Out:
#    tank_temperature_K  tank_temperature_C
# 0          288.150000           15.000000
# 1          288.149936           14.999936
# 2          288.149807           14.999807
# 3          288.149614           14.999614
# 4          288.149357           14.999357

# %%
plt.plot(df['t_s'],df['tank_temperature_C'])
plt.xlabel('Time (s)')
plt.ylabel('Tank Temperature (C)')
plt.title('Tank Temperature vs Time')
# Out:
# Text(0.5, 1.0, 'Tank Temperature vs Time')
